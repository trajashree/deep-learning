# %% [markdown]
# <a href="https://colab.research.google.com/github/trajashree/deep-learning/blob/main/Perceptron_WeightUpdation_learning_rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Training data for AND Gate
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# Desired outputs
Y = np.array([0, 0, 0, 1])

# Initialize weights and bias
weights = np.zeros(2)
bias = 0

# Learning rate
learning_rate = 0.5

# Number of training iterations
epochs = 20

# Training
for epoch in range(epochs):

    print(f"\nEpoch {epoch+1}")

    for i in range(len(X)):

        # Calculate weighted sum
        net = np.dot(X[i], weights) + bias

        # Step Activation Function
        if net >= 0:
            prediction = 1
        else:
            prediction = 0

        # Calculate error
        error = Y[i] - prediction

        # Update weights
        weights = weights + learning_rate * error * X[i]

        # Update bias
        bias = bias + learning_rate * error

        print(f"Input={X[i]}, Target={Y[i]}, Predicted={prediction}, Error={error}")
        print(f"Weights={weights}, Bias={bias}")

print("\nFinal Weights:", weights)
print("Final Bias:", bias)
# Out:
# Epoch 1
# Input=[0 0], Target=0, Predicted=1, Error=-1
# Weights=[0. 0.], Bias=-0.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[0. 0.], Bias=-0.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0. 0.], Bias=-0.5
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[0.5 0.5], Bias=0.0
#
# Epoch 2
# Input=[0 0], Target=0, Predicted=1, Error=-1
# Weights=[0.5 0.5], Bias=-0.5
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[0.5 0. ], Bias=-1.0
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0.5 0. ], Bias=-1.0
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[1.  0.5], Bias=-0.5
#
# Epoch 3
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-0.5
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[1. 0.], Bias=-1.0
# Input=[1 0], Target=0, Predicted=1, Error=-1
# Weights=[0.5 0. ], Bias=-1.5
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[1.  0.5], Bias=-1.0
#
# Epoch 4
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.0
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.0
# Input=[1 0], Target=0, Predicted=1, Error=-1
# Weights=[0.5 0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[1. 1.], Bias=-1.0
#
# Epoch 5
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1. 1.], Bias=-1.0
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 6
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 7
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 8
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 9
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 10
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 11
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 12
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 13
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 14
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 15
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 16
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 17
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 18
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 19
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Epoch 20
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Final Weights: [1.  0.5]
# Final Bias: -1.5

# %%
import numpy as np

# Training data for AND Gate
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# Desired outputs
Y = np.array([0, 0, 0, 1])

# Initialize weights and bias
weights = np.zeros(2)
bias = 0

# Learning rate
learning_rate = 1.0

# Number of training iterations
epochs = 5

# Training
for epoch in range(epochs):

    print(f"\nEpoch {epoch+1}")

    for i in range(len(X)):

        # Calculate weighted sum
        net = np.dot(X[i], weights) + bias

        # Step Activation Function
        if net >= 0:
            prediction = 1
        else:
            prediction = 0

        # Calculate error
        error = Y[i] - prediction

        # Update weights
        weights = weights + learning_rate * error * X[i]

        # Update bias
        bias = bias + learning_rate * error

        print(f"Input={X[i]}, Target={Y[i]}, Predicted={prediction}, Error={error}")
        print(f"Weights={weights}, Bias={bias}")

print("\nFinal Weights:", weights)
print("Final Bias:", bias)
# Out:
# Epoch 1
# Input=[0 0], Target=0, Predicted=1, Error=-1
# Weights=[0. 0.], Bias=-1.0
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[0. 0.], Bias=-1.0
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0. 0.], Bias=-1.0
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[1. 1.], Bias=0.0
#
# Epoch 2
# Input=[0 0], Target=0, Predicted=1, Error=-1
# Weights=[1. 1.], Bias=-1.0
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[1. 0.], Bias=-2.0
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1. 0.], Bias=-2.0
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[2. 1.], Bias=-1.0
#
# Epoch 3
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[2. 1.], Bias=-1.0
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[2. 0.], Bias=-2.0
# Input=[1 0], Target=0, Predicted=1, Error=-1
# Weights=[1. 0.], Bias=-3.0
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[2. 1.], Bias=-2.0
#
# Epoch 4
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[2. 1.], Bias=-2.0
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[2. 1.], Bias=-2.0
# Input=[1 0], Target=0, Predicted=1, Error=-1
# Weights=[1. 1.], Bias=-3.0
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[2. 2.], Bias=-2.0
#
# Epoch 5
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[2. 2.], Bias=-2.0
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[2. 1.], Bias=-3.0
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[2. 1.], Bias=-3.0
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[2. 1.], Bias=-3.0
#
# Final Weights: [2. 1.]
# Final Bias: -3.0

# %%
import numpy as np

# Training data for AND Gate
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# Desired outputs
Y = np.array([0, 0, 0, 1])

# Initialize weights and bias
weights = np.zeros(2)
bias = 0

# Learning rate
learning_rate = 0.1

# Number of training iterations
epochs = 5

# Training
for epoch in range(epochs):

    print(f"\nEpoch {epoch+1}")

    for i in range(len(X)):

        # Calculate weighted sum
        net = np.dot(X[i], weights) + bias

        # Step Activation Function
        if net >= 0:
            prediction = 1
        else:
            prediction = 0

        # Calculate error
        error = Y[i] - prediction

        # Update weights
        weights = weights + learning_rate * error * X[i]

        # Update bias
        bias = bias + learning_rate * error

        print(f"Input={X[i]}, Target={Y[i]}, Predicted={prediction}, Error={error}")
        print(f"Weights={weights}, Bias={bias}")

print("\nFinal Weights:", weights)
print("Final Bias:", bias)
# Out:
# Epoch 1
# Input=[0 0], Target=0, Predicted=1, Error=-1
# Weights=[0. 0.], Bias=-0.1
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[0. 0.], Bias=-0.1
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0. 0.], Bias=-0.1
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[0.1 0.1], Bias=0.0
#
# Epoch 2
# Input=[0 0], Target=0, Predicted=1, Error=-1
# Weights=[0.1 0.1], Bias=-0.1
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[0.1 0. ], Bias=-0.2
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0.1 0. ], Bias=-0.2
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[0.2 0.1], Bias=-0.1
#
# Epoch 3
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[0.2 0.1], Bias=-0.1
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[0.2 0. ], Bias=-0.2
# Input=[1 0], Target=0, Predicted=1, Error=-1
# Weights=[0.1 0. ], Bias=-0.30000000000000004
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[0.2 0.1], Bias=-0.20000000000000004
#
# Epoch 4
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[0.2 0.1], Bias=-0.20000000000000004
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[0.2 0.1], Bias=-0.20000000000000004
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0.2 0.1], Bias=-0.20000000000000004
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[0.2 0.1], Bias=-0.20000000000000004
#
# Epoch 5
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[0.2 0.1], Bias=-0.20000000000000004
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[0.2 0.1], Bias=-0.20000000000000004
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0.2 0.1], Bias=-0.20000000000000004
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[0.2 0.1], Bias=-0.20000000000000004
#
# Final Weights: [0.2 0.1]
# Final Bias: -0.20000000000000004

# %%
import numpy as np

# Training data for AND Gate
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# Desired outputs
Y = np.array([0, 0, 0, 1])

# Initialize weights and bias
weights = np.zeros(2)
bias = 0

# Learning rate
learning_rate = 0.5

# Number of training iterations
epochs = 5

# Training
for epoch in range(epochs):

    print(f"\nEpoch {epoch+1}")

    for i in range(len(X)):

        # Calculate weighted sum
        net = np.dot(X[i], weights) + bias

        # Step Activation Function
        if net >= 0:
            prediction = 1
        else:
            prediction = 0

        # Calculate error
        error = Y[i] - prediction

        # Update weights
        weights = weights + learning_rate * error * X[i]

        # Update bias
        bias = bias + learning_rate * error

        print(f"Input={X[i]}, Target={Y[i]}, Predicted={prediction}, Error={error}")
        print(f"Weights={weights}, Bias={bias}")

print("\nFinal Weights:", weights)
print("Final Bias:", bias)
# Out:
# Epoch 1
# Input=[0 0], Target=0, Predicted=1, Error=-1
# Weights=[0. 0.], Bias=-0.5
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[0. 0.], Bias=-0.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0. 0.], Bias=-0.5
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[0.5 0.5], Bias=0.0
#
# Epoch 2
# Input=[0 0], Target=0, Predicted=1, Error=-1
# Weights=[0.5 0.5], Bias=-0.5
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[0.5 0. ], Bias=-1.0
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[0.5 0. ], Bias=-1.0
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[1.  0.5], Bias=-0.5
#
# Epoch 3
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-0.5
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[1. 0.], Bias=-1.0
# Input=[1 0], Target=0, Predicted=1, Error=-1
# Weights=[0.5 0. ], Bias=-1.5
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[1.  0.5], Bias=-1.0
#
# Epoch 4
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.0
# Input=[0 1], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.0
# Input=[1 0], Target=0, Predicted=1, Error=-1
# Weights=[0.5 0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=0, Error=1
# Weights=[1. 1.], Bias=-1.0
#
# Epoch 5
# Input=[0 0], Target=0, Predicted=0, Error=0
# Weights=[1. 1.], Bias=-1.0
# Input=[0 1], Target=0, Predicted=1, Error=-1
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 0], Target=0, Predicted=0, Error=0
# Weights=[1.  0.5], Bias=-1.5
# Input=[1 1], Target=1, Predicted=1, Error=0
# Weights=[1.  0.5], Bias=-1.5
#
# Final Weights: [1.  0.5]
# Final Bias: -1.5
